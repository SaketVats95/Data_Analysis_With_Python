# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from pandas.plotting import register_matplotlib_converters
import math

# %%
df = pd.read_csv('fcc-forum-pageviews.csv')

# %%
_p = math.floor(len(df) * 0.025)
print(_p)
a = pd.DataFrame(df[:][_p+1:len(df) - _p-1]).reset_index(drop=True)
# Out:
# 32

# %%
a.head()
# Out:
#             value
# date
# 2016-06-11  16098
# 2016-06-12  16147
# 2016-06-13  17570
# 2016-06-14  19395
# 2016-06-15  18584

# %%
a['date'] = pd.to_datetime(a['date'])

# %%
a = a.set_index('date')

# %%
a.plot()
plt.show()

# %%
low = .025
high = .975
df_new = df.quantile([low, high])
df_new
# Out:
#             value
# 0.025   17876.400
# 0.975  177613.075
